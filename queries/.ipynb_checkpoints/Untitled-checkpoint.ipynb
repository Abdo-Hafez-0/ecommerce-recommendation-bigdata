# %%
from pymongo import MongoClient
from pymongo.errors import PyMongoError
from datetime import datetime, timezone
import pprint
import certifi

# %%
MONGO_URI = "mongodb+srv://abdohafez731_db_user:xQ4Nmj6FoicluMap@cluster0.p6b5wtu.mongodb.net/?retryWrites=true&w=majority"
DB_NAME   = "amazon_reviews_db"

def get_db():
    """
    Create a MongoClient and return the target database object.
    Call this once at startup and pass `db` into every function.
    """
    client = MongoClient(MONGO_URI)
    return client[DB_NAME]
db=get_db()
print(db.list_collection_names())
# Out:
# ---------------------------------------------------------------------------
# ServerSelectionTimeoutError               Traceback (most recent call last)
# Cell In[75], line 12
#      10     return client[DB_NAME]
#      11 db=get_db()
# ---> 12 print(db.list_collection_names())
#
# File ~/ProjectEnviro/lib/python3.12/site-packages/pymongo/synchronous/database.py:1254, in Database.list_collection_names(self, session, filter, comment, **kwargs)
#    1222 def list_collection_names(
#    1223     self,
#    1224     session: Optional[ClientSession] = None,
#    (...)   1227     **kwargs: Any,
#    1228 ) -> list[str]:
#    1229     """Get a list of all the collection names in this database.
#    1230
#    1231     For example, to list all non-system collections::
#    (...)   1252     .. versionadded:: 3.6
#    1253     """
# -> 1254     return self._list_collection_names(session, filter, comment, **kwargs)
#
# File ~/ProjectEnviro/lib/python3.12/site-packages/pymongo/synchronous/database.py:1219, in Database._list_collection_names(self, session, filter, comment, **kwargs)
#    1215     if not filter or (len(filter) == 1 and "name" in filter):
#    1216         kwargs["nameOnly"] = True
#    1218 return [
# -> 1219     result["name"] for result in self._list_collections_helper(session=session, **kwargs)
#    1220 ]
#
# File ~/ProjectEnviro/lib/python3.12/site-packages/pymongo/synchronous/database.py:1157, in Database._list_collections_helper(self, session, filter, comment, **kwargs)
#    1149 def _cmd(
#    1150     session: Optional[ClientSession],
#    1151     _server: Server,
#    1152     conn: Connection,
#    1153     read_preference: _ServerMode,
#    1154 ) -> CommandCursor[MutableMapping[str, Any]]:
#    1155     return self._list_collections(conn, session, read_preference=read_preference, **kwargs)
# -> 1157 return self._client._retryable_read(
#    1158     _cmd, read_pref, session, operation=_Op.LIST_COLLECTIONS
#    1159 )
#
# File ~/ProjectEnviro/lib/python3.12/site-packages/pymongo/synchronous/mongo_client.py:2076, in MongoClient._retryable_read(self, func, read_pref, session, operation, address, retryable, operation_id, is_run_command, is_aggregate_write)
#    2072 retryable = bool(
#    2073     retryable and self.options.retry_reads and not (session and session.in_transaction)
#    2074 )
#    2075 with self._tmp_session(session) as s:
# -> 2076     return self._retry_internal(
#    2077         func,
#    2078         s,
#    2079         None,
#    2080         operation,
#    2081         is_read=True,
#    2082         address=address,
#    2083         read_pref=read_pref,
#    2084         retryable=retryable,
#    2085         operation_id=operation_id,
#    2086         is_run_command=is_run_command,
#    2087         is_aggregate_write=is_aggregate_write,
#    2088     )
#
# File ~/ProjectEnviro/lib/python3.12/site-packages/pymongo/_csot.py:125, in apply.<locals>.csot_wrapper(self, *args, **kwargs)
#     123         with _TimeoutContext(timeout):
#     124             return func(self, *args, **kwargs)
# --> 125 return func(self, *args, **kwargs)
#
# File ~/ProjectEnviro/lib/python3.12/site-packages/pymongo/synchronous/mongo_client.py:2038, in MongoClient._retry_internal(self, func, session, bulk, operation, is_read, address, read_pref, retryable, operation_id, is_run_command, is_aggregate_write)
#    1995 @_csot.apply
#    1996 def _retry_internal(
#    1997     self,
#    (...)   2008     is_aggregate_write: bool = False,
#    2009 ) -> T:
#    2010     """Internal retryable helper for all client transactions.
#    2011
#    2012     :param func: Callback function we want to retry
#    (...)   2023     :return: Output of the calling func()
#    2024     """
#    2025     return _ClientConnectionRetryable(
#    2026         mongo_client=self,
#    2027         func=func,
#    2028         bulk=bulk,
#    2029         operation=operation,
#    2030         is_read=is_read,
#    2031         session=session,
#    2032         read_pref=read_pref,
#    2033         address=address,
#    2034         retryable=retryable,
#    2035         operation_id=operation_id,
#    2036         is_run_command=is_run_command,
#    2037         is_aggregate_write=is_aggregate_write,
# -> 2038     ).run()
#
# File ~/ProjectEnviro/lib/python3.12/site-packages/pymongo/synchronous/mongo_client.py:2811, in _ClientConnectionRetryable.run(self)
#    2809 self._check_last_error(check_csot=True)
#    2810 try:
# -> 2811     res = self._read() if self._is_read else self._write()
#    2812     # Track whether the transaction has completed a command.
#    2813     # If we need to apply backpressure to the first command,
#    2814     # we will need to revert back to starting state.
#    2815     if self._session is not None and self._session.in_transaction:
#
# File ~/ProjectEnviro/lib/python3.12/site-packages/pymongo/synchronous/mongo_client.py:3027, in _ClientConnectionRetryable._read(self)
#    3022 def _read(self) -> T:
#    3023     """Wrapper method for read-type retryable client executions
#    3024
#    3025     :return: Output for func()'s call
#    3026     """
# -> 3027     self._server = self._get_server()
#    3028     assert self._read_pref is not None, "Read Preference required on read calls"
#    3029     with self._client._conn_from_server(self._read_pref, self._server, self._session) as (
#    3030         conn,
#    3031         read_pref,
#    3032     ):
#
# File ~/ProjectEnviro/lib/python3.12/site-packages/pymongo/synchronous/mongo_client.py:2975, in _ClientConnectionRetryable._get_server(self)
#    2970 def _get_server(self) -> Server:
#    2971     """Retrieves a server object based on provided object context
#    2972
#    2973     :return: Abstraction to connect to server
#    2974     """
# -> 2975     return self._client._select_server(
#    2976         self._server_selector,
#    2977         self._session,
#    2978         self._operation,
#    2979         address=self._address,
#    2980         deprioritized_servers=self._deprioritized_servers,
#    2981         operation_id=self._operation_id,
#    2982     )
#
# File ~/ProjectEnviro/lib/python3.12/site-packages/pymongo/synchronous/mongo_client.py:1851, in MongoClient._select_server(self, server_selector, session, operation, address, deprioritized_servers, operation_id)
#    1849             raise AutoReconnect("server %s:%s no longer available" % address)  # noqa: UP031
#    1850     else:
# -> 1851         server = topology.select_server(
#    1852             server_selector,
#    1853             operation,
#    1854             deprioritized_servers=deprioritized_servers,
#    1855             operation_id=operation_id,
#    1856         )
#    1857     return server
#    1858 except PyMongoError as exc:
#    1859     # Server selection errors in a transaction are transient.
#
# File ~/ProjectEnviro/lib/python3.12/site-packages/pymongo/synchronous/topology.py:428, in Topology.select_server(self, selector, operation, server_selection_timeout, address, deprioritized_servers, operation_id)
#     418 def select_server(
#     419     self,
#     420     selector: Callable[[Selection], Selection],
#    (...)    425     operation_id: Optional[int] = None,
#     426 ) -> Server:
#     427     """Like select_servers, but choose a random server if several match."""
# --> 428     server = self._select_server(
#     429         selector,
#     430         operation,
#     431         server_selection_timeout,
#     432         address,
#     433         deprioritized_servers,
#     434         operation_id=operation_id,
#     435     )
#     436     if _csot.get_timeout():
#     437         _csot.set_rtt(server.description.min_round_trip_time)
#
# File ~/ProjectEnviro/lib/python3.12/site-packages/pymongo/synchronous/topology.py:402, in Topology._select_server(self, selector, operation, server_selection_timeout, address, deprioritized_servers, operation_id)
#     393 def _select_server(
#     394     self,
#     395     selector: Callable[[Selection], Selection],
#    (...)    400     operation_id: Optional[int] = None,
#     401 ) -> Server:
# --> 402     servers = self.select_servers(
#     403         selector,
#     404         operation,
#     405         server_selection_timeout,
#     406         address,
#     407         operation_id,
#     408         deprioritized_servers,
#     409     )
#     410     if len(servers) == 1:
#     411         return servers[0]
#
# File ~/ProjectEnviro/lib/python3.12/site-packages/pymongo/synchronous/topology.py:298, in Topology.select_servers(self, selector, operation, server_selection_timeout, address, operation_id, deprioritized_servers)
#     295     self.cleanup_monitors()
#     297 with self._lock:
# --> 298     server_descriptions = self._select_servers_loop(
#     299         selector,
#     300         server_timeout,
#     301         operation,
#     302         operation_id,
#     303         address,
#     304         deprioritized_servers=deprioritized_servers,
#     305     )
#     307     return [
#     308         cast(Server, self.get_server_by_address(sd.address)) for sd in server_descriptions
#     309     ]
#
# File ~/ProjectEnviro/lib/python3.12/site-packages/pymongo/synchronous/topology.py:359, in Topology._select_servers_loop(self, selector, timeout, operation, operation_id, address, deprioritized_servers)
#     348     if _SERVER_SELECTION_LOGGER.isEnabledFor(logging.DEBUG):
#     349         _debug_log(
#     350             _SERVER_SELECTION_LOGGER,
#     351             message=_ServerSelectionStatusMessage.FAILED,
#    (...)    357             failure=self._error_message(selector),
#     358         )
# --> 359     raise ServerSelectionTimeoutError(
#     360         f"{self._error_message(selector)}, Timeout: {timeout}s, Topology Description: {self.description!r}"
#     361     )
#     363 if not logged_waiting:
#     364     _debug_log(
#     365         _SERVER_SELECTION_LOGGER,
#     366         message=_ServerSelectionStatusMessage.WAITING,
#    (...)    372         remainingTimeMS=int(1000 * (end_time - time.monotonic())),
#     373     )
#
# ServerSelectionTimeoutError: SSL handshake failed: ac-rvapczz-shard-00-00.p6b5wtu.mongodb.net:27017: [SSL: TLSV1_ALERT_INTERNAL_ERROR] tlsv1 alert internal error (_ssl.c:1000) (configured timeouts: socketTimeoutMS: 20000.0ms, connectTimeoutMS: 20000.0ms),SSL handshake failed: ac-rvapczz-shard-00-01.p6b5wtu.mongodb.net:27017: [SSL: TLSV1_ALERT_INTERNAL_ERROR] tlsv1 alert internal error (_ssl.c:1000) (configured timeouts: socketTimeoutMS: 20000.0ms, connectTimeoutMS: 20000.0ms),SSL handshake failed: ac-rvapczz-shard-00-02.p6b5wtu.mongodb.net:27017: [SSL: TLSV1_ALERT_INTERNAL_ERROR] tlsv1 alert internal error (_ssl.c:1000) (configured timeouts: socketTimeoutMS: 20000.0ms, connectTimeoutMS: 20000.0ms), Timeout: 30s, Topology Description: <TopologyDescription id: 69ff481d2bfa0dcc4a2b9826, topology_type: ReplicaSetNoPrimary, servers: [<ServerDescription ('ac-rvapczz-shard-00-00.p6b5wtu.mongodb.net', 27017) server_type: Unknown, rtt: None, error=AutoReconnect('SSL handshake failed: ac-rvapczz-shard-00-00.p6b5wtu.mongodb.net:27017: [SSL: TLSV1_ALERT_INTERNAL_ERROR] tlsv1 alert internal error (_ssl.c:1000) (configured timeouts: socketTimeoutMS: 20000.0ms, connectTimeoutMS: 20000.0ms)')>, <ServerDescription ('ac-rvapczz-shard-00-01.p6b5wtu.mongodb.net', 27017) server_type: Unknown, rtt: None, error=AutoReconnect('SSL handshake failed: ac-rvapczz-shard-00-01.p6b5wtu.mongodb.net:27017: [SSL: TLSV1_ALERT_INTERNAL_ERROR] tlsv1 alert internal error (_ssl.c:1000) (configured timeouts: socketTimeoutMS: 20000.0ms, connectTimeoutMS: 20000.0ms)')>, <ServerDescription ('ac-rvapczz-shard-00-02.p6b5wtu.mongodb.net', 27017) server_type: Unknown, rtt: None, error=AutoReconnect('SSL handshake failed: ac-rvapczz-shard-00-02.p6b5wtu.mongodb.net:27017: [SSL: TLSV1_ALERT_INTERNAL_ERROR] tlsv1 alert internal error (_ssl.c:1000) (configured timeouts: socketTimeoutMS: 20000.0ms, connectTimeoutMS: 20000.0ms)')>]>

# %%
# CREATE OPERATIONS
def create_user(db, user_data: dict) -> str:
    try:
        result = db.users.insert_one(user_data)
        print(f"[CREATE] User inserted — _id: {result.inserted_id}")
        return str(result.inserted_id)
    except PyMongoError as e:
        print(f"[ERROR] create_user: {e}")
        raise

# %%
# CREATE PRODUCT
def create_product(db, product_data: dict) -> str:
    try:
        result = db.products.insert_one(product_data)
        print(f"[CREATE] Product inserted — _id: {result.inserted_id}")
        return str(result.inserted_id)
    except PyMongoError as e:
        print(f"[ERROR] create_product: {e}")
        raise

# %%
# CREATE REVIEW
def create_review(db, review_data: dict) -> str:
    try:
        result = db.reviews.insert_one(review_data)
        print(f"[CREATE] Review inserted — _id: {result.inserted_id}")
        return str(result.inserted_id)
    except PyMongoError as e:
        print(f"[ERROR] create_review: {e}")
        raise

# %%
# CREATE MANY REVIEWS 
def create_many_reviews(db, reviews_list: list) -> list:
    try:
        result = db.reviews.insert_many(reviews_list, ordered=False)
        ids = [str(i) for i in result.inserted_ids]
        print(f"[CREATE] {len(ids)} reviews inserted.")
        return ids
    except PyMongoError as e:
        print(f"[ERROR] create_many_reviews: {e}")
        raise

# %%
# CREATE MANY PRODUCTS

def create_many_products(db, products_list: list) -> list:
    try:
        result = db.products.insert_many(products_list, ordered=False)
        ids = [str(i) for i in result.inserted_ids]
        print(f"[CREATE] {len(ids)} products inserted.")
        return ids
    except PyMongoError as e:
        print(f"[ERROR] create_many_products: {e}")
        raise

# %%
# READ
# READ REVIEW BY ID 

def get_review_by_id(db, reviewer_id: str, asin: str) -> dict | None:
    try:
        doc = db.reviews.find_one({"reviewerID": reviewer_id, "asin": asin})
        return doc
    except PyMongoError as e:
        print(f"[ERROR] get_review_by_id: {e}")
        raise

# %%
# READ USER 

def get_user(db, reviewer_id: str) -> dict | None:
    try:
        return db.users.find_one({"reviewerID": reviewer_id})
    except PyMongoError as e:
        print(f"[ERROR] get_user: {e}")
        raise

# %%
# READ PRODUCT
def get_product(db, asin: str) -> dict | None:
    try:
        return db.products.find_one({"asin": asin})
    except PyMongoError as e:
        print(f"[ERROR] get_product: {e}")
        raise

# %%
# GET REVIEWS BY PRODUCT
def get_reviews_by_product(db, asin: str, limit: int = 20) -> list:
    try:
        cursor = (
            db.reviews
            .find({"asin": asin})
            .sort("unixReviewTime", -1)
            .limit(limit)
        )
        return list(cursor)
    except PyMongoError as e:
        print(f"[ERROR] get_reviews_by_product: {e}")
        raise

# %%
#GET REVIEWS BY USER

def get_reviews_by_user(db, reviewer_id: str) -> list:
    try:
        return list(db.reviews.find({"reviewerID": reviewer_id}))
    except PyMongoError as e:
        print(f"[ERROR] get_reviews_by_user: {e}")
        raise

# %%
# GET VERIFIED REVIEWS

def get_verified_reviews(db, min_rating: float = 4.0, limit: int = 50) -> list:
    try:
        cursor = (
            db.reviews
            .find({"verified": True, "overall": {"$gte": min_rating}})
            .limit(limit)
        )
        return list(cursor)
    except PyMongoError as e:
        print(f"[ERROR] get_verified_reviews: {e}")
        raise

# %%
# PROJECTION
def get_review_summaries(db, asin: str, limit: int = 10) -> list:
    """
    Return only selected fields for reviews of a product.
    Uses projection to exclude heavy fields (reviewText, style).

    Projection dict:
        1  → include
        0  → exclude
        _id is included by default; set to 0 to hide it.
    """
    projection = {
        "_id"           : 0,   # hide Mongo internal id
        "reviewerID"    : 1,
        "reviewerName"  : 1,
        "overall"       : 1,
        "summary"       : 1,
        "verified"      : 1,
        "reviewTime"    : 1,
    }
    try:
        cursor = (
            db.reviews
            .find({"asin": asin}, projection)
            .limit(limit)
        )
        return list(cursor)
    except PyMongoError as e:
        print(f"[ERROR] get_review_summaries: {e}")
        raise

# %%
# GET USER MINIMAL

def get_user_minimal(db, reviewer_id: str) -> dict | None:
    """Return only reviewerID and reviewerName for a user."""
    projection = {"_id": 0, "reviewerID": 1, "reviewerName": 1}
    try:
        return db.users.find_one({"reviewerID": reviewer_id}, projection)
    except PyMongoError as e:
        print(f"[ERROR] get_user_minimal: {e}")
        raise

# %%
# UPDATE
def update_review_vote(db, reviewer_id: str, asin: str, new_vote: str) -> int:
    try:
        result = db.reviews.update_one(
            {"reviewerID": reviewer_id, "asin": asin},   # filter
            {"$set": {"vote": new_vote,                   # update
                       "updatedAt": datetime.now(timezone.utc)}}
        )
        print(f"[UPDATE] Matched: {result.matched_count} | Modified: {result.modified_count}")
        return result.modified_count
    except PyMongoError as e:
        print(f"[ERROR] update_review_vote: {e}")
        raise

# %%
def update_product_info(db, asin: str, update_fields: dict) -> int:
    """
    Update arbitrary fields on a product document.
    `update_fields` is a plain dict of field → new value.
    Returns the number of documents modified.
    """
    try:
        result = db.products.update_one(
            {"asin": asin},
            {"$set": {**update_fields,
                      "updatedAt": datetime.now(timezone.utc)}}
        )
        print(f"[UPDATE] Product '{asin}' — Modified: {result.modified_count}")
        return result.modified_count
    except PyMongoError as e:
        print(f"[ERROR] update_product_info: {e}")
        raise

# %%
def mark_reviews_unverified_below_rating(db, asin: str, threshold: float = 2.0) -> int:
    """
    For a given product, mark all low-rated reviews as unverified.
    Demonstrates update_many with $set.
    Returns count of modified documents.
    """
    try:
        result = db.reviews.update_many(
            {"asin": asin, "overall": {"$lt": threshold}},
            {"$set": {"verified": False,
                      "updatedAt": datetime.now(timezone.utc)}}
        )
        print(f"[UPDATE MANY] Matched: {result.matched_count} | Modified: {result.modified_count}")
        return result.modified_count
    except PyMongoError as e:
        print(f"[ERROR] mark_reviews_unverified_below_rating: {e}")
        raise

# %%
def add_flag_to_all_reviews(db, flag_key: str, flag_value) -> int:
    """
    Add a new field to EVERY review document (bulk schema migration helper).
    Example usage: add_flag_to_all_reviews(db, "migrated", True)
    Returns count of modified documents.
    """
    try:
        result = db.reviews.update_many(
            {},                                        # match all
            {"$set": {flag_key: flag_value,
                      "updatedAt": datetime.now(timezone.utc)}}
        )
        print(f"[UPDATE MANY] Flag '{flag_key}' applied to {result.modified_count} reviews.")
        return result.modified_count
    except PyMongoError as e:
        print(f"[ERROR] add_flag_to_all_reviews: {e}")
        raise

# %%
# DELETE 

def delete_review(db, reviewer_id: str, asin: str) -> int:
    """
    Permanently delete a single review.
    Returns 1 if deleted, 0 if not found.
    ⚠  Hard delete — cannot be undone.
    """
    try:
        result = db.reviews.delete_one({"reviewerID": reviewer_id, "asin": asin})
        print(f"[DELETE] Deleted count: {result.deleted_count}")
        return result.deleted_count
    except PyMongoError as e:
        print(f"[ERROR] delete_review: {e}")
        raise

# %%
def delete_user(db, reviewer_id: str) -> int:
    """Permanently delete a single user document."""
    try:
        result = db.users.delete_one({"reviewerID": reviewer_id})
        print(f"[DELETE] User deleted: {result.deleted_count}")
        return result.deleted_count
    except PyMongoError as e:
        print(f"[ERROR] delete_user: {e}")
        raise

# %%
def delete_reviews_by_product(db, asin: str) -> int:
    """
    Permanently delete ALL reviews for a given product.
    Use with caution — cascading hard delete.
    Returns count of deleted documents.
    """
    try:
        result = db.reviews.delete_many({"asin": asin})
        print(f"[DELETE MANY] Deleted {result.deleted_count} reviews for asin '{asin}'.")
        return result.deleted_count
    except PyMongoError as e:
        print(f"[ERROR] delete_reviews_by_product: {e}")
        raise

# %%
def delete_unverified_low_rated(db, max_rating: float = 1.0) -> int:
    """
    Delete all unverified reviews with overall <= max_rating.
    Useful for cleaning spam/fake reviews.
    """
    try:
        result = db.reviews.delete_many(
            {"verified": False, "overall": {"$lte": max_rating}}
        )
        print(f"[DELETE MANY] Removed {result.deleted_count} spam reviews.")
        return result.deleted_count
    except PyMongoError as e:
        print(f"[ERROR] delete_unverified_low_rated: {e}")
        raise

# %%
def soft_delete_review(db, reviewer_id: str, asin: str) -> int:
    """
    Soft-delete a review by stamping a `deleted_at` timestamp.
    The document remains in the collection but is logically removed.
    All read queries should add {"deleted_at": {"$exists": False}} to
    exclude soft-deleted docs.
    Returns 1 if stamped, 0 if not found.
    """
    try:
        result = db.reviews.update_one(
            {
                "reviewerID": reviewer_id,
                "asin"      : asin,
                "deleted_at": {"$exists": False}   # don't double-delete
            },
            {"$set": {"deleted_at": datetime.now(timezone.utc)}}
        )
        print(f"[SOFT DELETE] Modified: {result.modified_count}")
        return result.modified_count
    except PyMongoError as e:
        print(f"[ERROR] soft_delete_review: {e}")
        raise

# %%
def restore_soft_deleted_review(db, reviewer_id: str, asin: str) -> int:
    """
    Restore a previously soft-deleted review by removing the deleted_at field.
    """
    try:
        result = db.reviews.update_one(
            {"reviewerID": reviewer_id, "asin": asin},
            {"$unset": {"deleted_at": ""}}
        )
        print(f"[RESTORE] Modified: {result.modified_count}")
        return result.modified_count
    except PyMongoError as e:
        print(f"[ERROR] restore_soft_deleted_review: {e}")
        raise

# %%
def get_active_reviews(db, asin: str, limit: int = 20) -> list:
    """
    Read helper: fetch only reviews that have NOT been soft-deleted.
    Always use this instead of a raw find() to respect soft deletes.
    """
    try:
        cursor = (
            db.reviews
            .find({"asin": asin, "deleted_at": {"$exists": False}})
            .sort("unixReviewTime", -1)
            .limit(limit)
        )
        return list(cursor)
    except PyMongoError as e:
        print(f"[ERROR] get_active_reviews: {e}")
        raise

# %%
    db = get_db()
    pp = pprint.PrettyPrinter(indent=2)

    print("\n" + "="*60)
    print("  SECTION 1 — CREATE")
    print("="*60)

    # ── insert_one: user ──────────────────────────────────
    sample_user = {
        "reviewerID"  : "TEST_USER_001",
        "reviewerName": "Alice Tester",
        "profile"     : {                  # embedded one-to-one doc
            "email"     : "alice@example.com",
            "joinedYear": 2021,
            "country"   : "US"
        }
    }
    create_user(db, sample_user)
